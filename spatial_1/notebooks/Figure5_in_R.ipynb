# %%
suppressPackageStartupMessages(library(ggsankey))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(tidyverse))

dpi = 300
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”

# %%
df_sankey <- read.delim2("../data/fig5_sankey_plot_cellpattern_progression.csv", sep = ",", stringsAsFactors = TRUE)

# %%
options(repr.plot.height = 20, repr.plot.width = 30, repr.plot.res = dpi)

ggplot(df_sankey, aes(x = factor(df_sankey$x, levels = c("PRES", "EDAD", "MDAD", "ODAD")), 
               next_x = factor(df_sankey$next_x, levels = c("PRES", "EDAD", "MDAD", "ODAD")), 
               node = node, 
               next_node = next_node,
               fill = factor(node),
               label = node)) +
    geom_sankey(flow.alpha = 0.5, node.color = 1) +
    geom_sankey_label(size = 12, color = 1, fill = "white") +
    scale_fill_viridis_d() +
    theme_sankey(base_size = 16) +
    theme(
        axis.text.x = element_text(size = 36), 
        axis.title.x = element_text(size = 48),
        axis.title.y = element_text(size = 48, vjust = -25),
        legend.position = "none"
    ) +
#     guides(fill = guide_legend(title = "Factor")) +

    xlab("Pathology") + ylab("Factor")
# Out:
# Warning message:
# “Use of `df_sankey$x` is discouraged. Use `x` instead.”
# Warning message:
# “Use of `df_sankey$next_x` is discouraged. Use `next_x` instead.”
# Warning message:
# “Use of `df_sankey$x` is discouraged. Use `x` instead.”
# Warning message:
# “Use of `df_sankey$next_x` is discouraged. Use `next_x` instead.”
# Warning message:
# “Use of `df_sankey$x` is discouraged. Use `x` instead.”
# Warning message:
# “Use of `df_sankey$next_x` is discouraged. Use `next_x` instead.”
# plot without title
